# %% [markdown]
# # **Movies Recommendation System**

# %%
import pandas as pd

# %%
movies = pd.read_csv('/content/movie_dataset.csv')

# %%
movies.head(5)
# Out:
#     id                     title release_date               genres  \
# 0  278  The Shawshank Redemption   1994-09-23         Drama, Crime
# 1  238             The Godfather   1972-03-14         Drama, Crime
# 2  240     The Godfather Part II   1974-12-20         Drama, Crime
# 3  424          Schindler's List   1993-12-15  Drama, History, War
# 4  389              12 Angry Men   1957-04-10                Drama
#
#   original_language                                           overview  \
# 0                en  Framed in the 1940s for the double murder of h...
# 1                en  Spanning the years 1945 to 1955, a chronicle o...
# 2                en  In the continuing saga of the Corleone crime f...
# 3                en  The true story of how businessman Oskar Schind...
# 4                en  The defense and the prosecution have rested an...
#
#    popularity  vote_count  vote_average
# 0     124.582       26066         8.703
# 1     199.537       19757         8.695
# 2     129.056       11936         8.577
# 3     108.254       15341         8.567
# 4      69.908        8212         8.500

# %%
movies.describe()
# Out:
#                  id   popularity    vote_count  vote_average
# count  9.335000e+03  9335.000000   9335.000000   9335.000000
# mean   1.872435e+05    46.528424   1970.508302      6.634202
# std    2.485417e+05    61.436705   3091.371593      0.787368
# min    2.000000e+00     0.600000    300.000000      2.208000
# 25%    1.002600e+04    20.862500    467.000000      6.102500
# 50%    3.656800e+04    31.493000    844.000000      6.656000
# 75%    3.409755e+05    50.998000   1962.000000      7.200000
# max    1.212073e+06  1611.660000  35633.000000      8.703000

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9335 entries, 0 to 9334
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 9335 non-null   int64
#  1   title              9335 non-null   object
#  2   release_date       9335 non-null   object
#  3   genres             9335 non-null   object
#  4   original_language  9335 non-null   object
#  5   overview           9335 non-null   object
#  6   popularity         9335 non-null   float64
#  7   vote_count         9335 non-null   int64
#  8   vote_average       9335 non-null   float64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 656.5+ KB

# %%
movies.isnull().sum()
# Out:
# id                   0
# title                0
# release_date         0
# genres               0
# original_language    0
# overview             0
# popularity           0
# vote_count           0
# vote_average         0
# dtype: int64

# %%
movies.columns
# Out:
# Index(['id', 'title', 'release_date', 'genres', 'original_language',
#        'overview', 'popularity', 'vote_count', 'vote_average'],
#       dtype='object')

# %%
movies = movies[['id', 'title', 'overview', 'genres']]

# %%
movies
# Out:
#          id                       title  \
# 0       278    The Shawshank Redemption
# 1       238               The Godfather
# 2       240       The Godfather Part II
# 3       424            Schindler's List
# 4       389                12 Angry Men
# ...     ...                         ...
# 9330  12142           Alone in the Dark
# 9331  13805              Disaster Movie
# 9332  11059           House of the Dead
# 9333  14164        Dragonball Evolution
# 9334  40016  Birdemic: Shock and Terror
#
#                                                overview  \
# 0     Framed in the 1940s for the double murder of h...
# 1     Spanning the years 1945 to 1955, a chronicle o...
# 2     In the continuing saga of the Corleone crime f...
# 3     The true story of how businessman Oskar Schind...
# 4     The defense and the prosecution have rested an...
# ...                                                 ...
# 9330  Edward Carnby is a private investigator specia...
# 9331  The filmmaking team behind the hits "Scary Mov...
# 9332  Set on an island off the coast, a techno rave ...
# 9333  On his 18th birthday, Goku receives a mystical...
# 9334  A platoon of eagles and vultures attacks the r...
#
#                                                  genres
# 0                                          Drama, Crime
# 1                                          Drama, Crime
# 2                                          Drama, Crime
# 3                                   Drama, History, War
# 4                                                 Drama
# ...                                                 ...
# 9330                            Action, Fantasy, Horror
# 9331                            Comedy, Science Fiction
# 9332                           Horror, Action, Thriller
# 9333  Action, Adventure, Fantasy, Science Fiction, T...
# 9334                          Romance, Horror, Thriller
#
# [9335 rows x 4 columns]

# %%
movies['tags'] = movies['overview'] + movies['genres']

# %%
movies
# Out:
#          id                       title  \
# 0       278    The Shawshank Redemption
# 1       238               The Godfather
# 2       240       The Godfather Part II
# 3       424            Schindler's List
# 4       389                12 Angry Men
# ...     ...                         ...
# 9330  12142           Alone in the Dark
# 9331  13805              Disaster Movie
# 9332  11059           House of the Dead
# 9333  14164        Dragonball Evolution
# 9334  40016  Birdemic: Shock and Terror
#
#                                                overview  \
# 0     Framed in the 1940s for the double murder of h...
# 1     Spanning the years 1945 to 1955, a chronicle o...
# 2     In the continuing saga of the Corleone crime f...
# 3     The true story of how businessman Oskar Schind...
# 4     The defense and the prosecution have rested an...
# ...                                                 ...
# 9330  Edward Carnby is a private investigator specia...
# 9331  The filmmaking team behind the hits "Scary Mov...
# 9332  Set on an island off the coast, a techno rave ...
# 9333  On his 18th birthday, Goku receives a mystical...
# 9334  A platoon of eagles and vultures attacks the r...
#
#                                                  genres  \
# 0                                          Drama, Crime
# 1                                          Drama, Crime
# 2                                          Drama, Crime
# 3                                   Drama, History, War
# 4                                                 Drama
# ...                                                 ...
# 9330                            Action, Fantasy, Horror
# 9331                            Comedy, Science Fiction
# 9332                           Horror, Action, Thriller
# 9333  Action, Adventure, Fantasy, Science Fiction, T...
# 9334                          Romance, Horror, Thriller
#
#                                                    tags
# 0     Framed in the 1940s for the double murder of h...
# 1     Spanning the years 1945 to 1955, a chronicle o...
# 2     In the continuing saga of the Corleone crime f...
# 3     The true story of how businessman Oskar Schind...
# 4     The defense and the prosecution have rested an...
# ...                                                 ...
# 9330  Edward Carnby is a private investigator specia...
# 9331  The filmmaking team behind the hits "Scary Mov...
# 9332  Set on an island off the coast, a techno rave ...
# 9333  On his 18th birthday, Goku receives a mystical...
# 9334  A platoon of eagles and vultures attacks the r...
#
# [9335 rows x 5 columns]

# %%
new_data = movies.drop(columns=['overview', 'genres'])

# %%
new_data
# Out:
#          id                       title  \
# 0       278    The Shawshank Redemption
# 1       238               The Godfather
# 2       240       The Godfather Part II
# 3       424            Schindler's List
# 4       389                12 Angry Men
# ...     ...                         ...
# 9330  12142           Alone in the Dark
# 9331  13805              Disaster Movie
# 9332  11059           House of the Dead
# 9333  14164        Dragonball Evolution
# 9334  40016  Birdemic: Shock and Terror
#
#                                                    tags
# 0     Framed in the 1940s for the double murder of h...
# 1     Spanning the years 1945 to 1955, a chronicle o...
# 2     In the continuing saga of the Corleone crime f...
# 3     The true story of how businessman Oskar Schind...
# 4     The defense and the prosecution have rested an...
# ...                                                 ...
# 9330  Edward Carnby is a private investigator specia...
# 9331  The filmmaking team behind the hits "Scary Mov...
# 9332  Set on an island off the coast, a techno rave ...
# 9333  On his 18th birthday, Goku receives a mystical...
# 9334  A platoon of eagles and vultures attacks the r...
#
# [9335 rows x 3 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv = CountVectorizer(max_features=10000, stop_words='english')

# %%
cv
# Out:
# CountVectorizer(max_features=10000, stop_words='english')

# %%
vectors = cv.fit_transform(new_data['tags'].values.astype('U')).toarray()

# %%
vectors.shape
# Out:
# (9335, 10000)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity = cosine_similarity(vectors)

# %%
similarity
# Out:
# array([[1.        , 0.13231403, 0.11764706, ..., 0.        , 0.        ,
#         0.        ],
#        [0.13231403, 1.        , 0.47633051, ..., 0.        , 0.        ,
#         0.        ],
#        [0.11764706, 0.47633051, 1.        , ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.        , 0.        , 0.        , ..., 1.        , 0.04938648,
#         0.10223973],
#        [0.        , 0.        , 0.        , ..., 0.04938648, 1.        ,
#         0.03450328],
#        [0.        , 0.        , 0.        , ..., 0.10223973, 0.03450328,
#         1.        ]])

# %%
new_data[new_data['title']=="The Godfather"].index[0]
# Out:
# 1

# %%
distance = sorted(list(enumerate(similarity[1])), reverse=True, key=lambda vectors:vectors[1])
for i in distance[0:5]:
  print(new_data.iloc[i[0]].title)
# Out:
# The Godfather
# The Godfather Part II
# Blood Ties
# Joker
# Felon

# %%
def recommend(movies):
  index = new_data[new_data['title']==movies].index[0]
  distance = sorted(list(enumerate(similarity[index])), reverse=True, key=lambda vectors:vectors[1])
  for i in distance[0:5]:
    print(new_data.iloc[i[0]].title)

# %%
recommend('Iron Man')
# Out:
# Iron Man
# Iron Man 3
# Avengers: Age of Ultron
# Guardians of the Galaxy Vol. 2
# The New Mutants

# %%
import pickle

# %%
pickle.dump(new_data, open('movies.pkl', 'wb'))

# %%
pickle.dump(similarity, open('similarity.pkl', 'wb'))

# %%
pickle.load(open('movies.pkl', 'rb'))
# Out:
#          id                       title  \
# 0       278    The Shawshank Redemption
# 1       238               The Godfather
# 2       240       The Godfather Part II
# 3       424            Schindler's List
# 4       389                12 Angry Men
# ...     ...                         ...
# 9330  12142           Alone in the Dark
# 9331  13805              Disaster Movie
# 9332  11059           House of the Dead
# 9333  14164        Dragonball Evolution
# 9334  40016  Birdemic: Shock and Terror
#
#                                                    tags
# 0     Framed in the 1940s for the double murder of h...
# 1     Spanning the years 1945 to 1955, a chronicle o...
# 2     In the continuing saga of the Corleone crime f...
# 3     The true story of how businessman Oskar Schind...
# 4     The defense and the prosecution have rested an...
# ...                                                 ...
# 9330  Edward Carnby is a private investigator specia...
# 9331  The filmmaking team behind the hits "Scary Mov...
# 9332  Set on an island off the coast, a techno rave ...
# 9333  On his 18th birthday, Goku receives a mystical...
# 9334  A platoon of eagles and vultures attacks the r...
#
# [9335 rows x 3 columns]
